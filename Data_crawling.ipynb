# %%
import requests
from bs4 import BeautifulSoup

print("requests:{requests.__version__}", "beautifulsoup:{BeautifulSoup.__version__}")
# Out:
# requests:{requests.__version__} beautifulsoup:{BeautifulSoup.__version__}

# %%
url = 'https://ensiplay.com/teams/lol'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    table_data = soup.find('table', class_ = "cq-table teams-table")
    #Extract the rows of the table data
    rows = table_data.find_all('tr')
    
    for row in rows:
        column = row.find_all('td')
        # print(column)
        if column:
            rank_and_subrank = column[0].text.strip().split('\n')
            new_rank = [x for x in rank_and_subrank if x != '']
            rank = new_rank[0]
            if len(new_rank) > 1:
                subrank = new_rank[1]
            else:
                subrank = "None"
            
            team_name = column[1].text.strip()

            Total_value = column[2].text.strip()

            ENSI_score = column[3].text.strip()

            Country = column[4].text.strip()
            print(Country)

            Winrate_and_Streak = column[5].text.strip().split('\n')
            Winrate = Winrate_and_Streak[0]
            # print(len(Winrate_and_Streak))
            Streak_procesing = [x for x in Winrate_and_Streak[1].split(' ') if x != '' and x != '%' and x != '/']
            if len(Streak_procesing) < 1:
                Streak = "None"
            else:
                Streak = Streak_procesing[0]
                
            Next_match = column[6].text.strip()
           
            print(f"Rank:{rank}\
                \nSub rank: {subrank}\
                \nTeam name: {team_name}\
                \nTeam value: {Total_value}\
                \nENSI score: {ENSI_score}\
                \nCountry: {Country}\
                \nWinrate & Streak: {Winrate}% & {Streak}\
                \nNext match: {Next_match}")
# Out:
# Rank:1
# Sub rank: +1
# Team name: Gen.G Esports
# Team value: $ 773,750
# ENSI score: 1792
# Country:
# Winrate & Streak: 100% & 11
# Next match: 18 hours from now
#
# Rank:2
# Sub rank: -1
# Team name: JD Gaming
# Team value: $ 1,275,129
# ENSI score: 1763
# Country:
# Winrate & Streak: 90% & None
# Next match: 2 days from now
#
# Rank:3
# Sub rank: +4
# Team name: Bilibili Gaming
# Team value: $ 107,244
# ENSI score: 1723
# Country:
# Winrate & Streak: 90% & 8
# Next match: 2 days from now
#
# Rank:4
# Sub rank: -1
# Team name: T1
# Team value: $ 5,240,775
# ENSI score: 1718
# Country:
# Winrate & Streak: 60% & None
# Next match: 15 hours from now
#
# Rank:5
# Sub rank: -1
# Team name: Istanbul Wildcats
# Team value: -
# ENSI score: 1700
# Country:
# Winrate & Streak: 90% & None
# Next match: 1 hour from now
#
# Rank:6
# Sub rank: None
# Team name: Unicorns of Love Sexy Edition
# Team value: -
# ENSI score: 1693
# Country:
# Winrate & Streak: 80% & None
# Next match: 44 seconds from now
#
# Rank:7
# Sub rank: -2
# Team name: PSG Talon
# Team value: -
# ENSI score: 1692
# Country:
# Winrate & Streak: 70% & None
# Next match: 20 hours from now
#
# Rank:8
# Sub rank: None
# Team name: DetonatioN FocusMe
# Team value: -
# ENSI score: 1683
# Country:
# Winrate & Streak: 70% & 5
# Next match: 2 days from now
#
# Rank:9
# Sub rank: +5
# Team name: Anorthosis Famagusta Esports
# Team value: -
# ENSI score: 1676
# Country:
# Winrate & Streak: 100% & 10
# Next match: 4 days from now
#
# Rank:10
# Sub rank: +3
# Team name: Team GO
# Team value: $ 225,018
# ENSI score: 1668
# Country:
# Winrate & Streak: 70% & None
# Next match: 2 hours from now
#
# Rank:11
# Sub rank: +5
# Team name: Top Esports Challenger
# Team value: -
# ENSI score: 1666
# Country:
# Winrate & Streak: 90% & None
# Next match: 1 day from now
#
# Rank:12
# Sub rank: +13
# Team name: SK Gaming Prime
# Team value: -
# ENSI score: 1650
# Country:
# Winrate & Streak: 80% & None
# Next match: 3 hours from now
#
# Rank:13
# Sub rank: +2
# Team name: Macko Esports
# Team value: -
# ENSI score: 1650
# Country:
# Winrate & Streak: 90% & None
# Next match: 3 hours from now
#
# Rank:14
# Sub rank: -2
# Team name: Partizan Esports
# Team value: -
# ENSI score: 1645
# Country:
# Winrate & Streak: 80% & 8
# Next match: 3 hours from now
#
# Rank:15
# Sub rank: +2
# Team name: LDLC OL
# Team value: -
# ENSI score: 1641
# Country:
# Winrate & Streak: 50% & None
# Next match: 55 minutes from now
#
# Rank:16
# Sub rank: -7
# Team name: GAM Esports
# Team value: $ 359,589
# ENSI score: 1639
# Country:
# Winrate & Streak: 60% & None
# Next match: 20 hours from now
#
# Rank:17
# Sub rank: +2
# Team name: G2 Esports
# Team value: $ 2,634,366
# ENSI score: 1638
# Country:
# Winrate & Streak: 80% & 7
# Next match: 3 days from now
#
# Rank:18
# Sub rank: +5
# Team name: KT Rolster
# Team value: $ 563,235
# ENSI score: 1634
# Country:
# Winrate & Streak: 90% & 9
# Next match: 2 days from now
#
# Rank:19
# Sub rank: +3
# Team name: Dplus KIA Challengers
# Team value: -
# ENSI score: 1633
# Country:
# Winrate & Streak: 100% & 14
# Next match: 12 hours from now
#
# Rank:20
# Sub rank: +1
# Team name: We Love Gaming
# Team value: -
# ENSI score: 1624
# Country:
# Winrate & Streak: 90% & None
# Next match: 4 days from now

# %%
print(rows[20])
# Out:
# <tr class="teams-table__row" data-ahref="https://ensiplay.com/teams/lol/we-love-gaming">
# <td>
# <div class="rank-change teams-table__rank">
# <div class="rank-change__rank">20</div>
# <div class="rank-change__change">
# <span class="rank-change__arrow rank-change__arrow--up"></span>
# <sup>+1</sup>
# </div>
# </div>
# </td>
# <td class="teams-table__team">
# <img alt="We Love Gaming" height="30" loading="lazy" src="https://storage.ensiplay.com/logos/teams/e8095cafb47de793d6c69744253c211e_t.png" width="30"/>
# <a href="https://ensiplay.com/teams/lol/we-love-gaming">We Love Gaming</a>
# </td>
# <td class="cq-table--a-right desktop-only">-</td>
# <td class="cq-table--a-right">1624</td>
# <td class="teams-table__country cq-table--a-center desktop-only">
# <img alt="Greece" height="67" loading="lazy" src="https://ensiplay.com/media/flags/gr.png" width="100"/>
# </td>
# <td class="lg-desktop-only">
# <div class="f aic"><i class="ensi-icon-arrow-up winrate-trend winrate-trend--up"></i>90
#             % <span class="winrate-trend-sep">/</span> <span title="Current Streak: 1 Lose"><span class="match__streak match__streak--lose"></span></span></div>
# </td>
# <td class="desktop-tablet-only desktop-only">4 days from now</td>
# <td><i class="ensi-icon-chevron-right-thin"></i></td>
# </tr>
